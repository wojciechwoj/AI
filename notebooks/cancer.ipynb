# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url_data = 'https://raw.githubusercontent.com/wojciechwoj/AI/main/data/data.csv'
url_heart = 'https://raw.githubusercontent.com/wojciechwoj/AI/main/data/heart.csv'

df_data = pd.read_csv(url_data)
df_heart = pd.read_csv(url_heart)

# %%
liczba_probek, liczba_kolumn = df_data.shape
print(f"Liczba próbek: {liczba_probek}")
print(f"Liczba kolumn: {liczba_kolumn}")
# Out:
# Liczba próbek: 569
# Liczba kolumn: 33

# %%
klasy = 'diagnosis'

if klasy in df_data.columns:
    ile_klas = df_data[klasy].value_counts()
    print("Rozkład klas M i B:")
    print(ile_klas)
# Out:
# Rozkład klas M i B:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
sns.histplot(data=df_data, x='radius_mean')
plt.show()

# %%
sns.boxplot(data=df_data, x='diagnosis', y='radius_mean')
plt.show()
